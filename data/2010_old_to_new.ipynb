# %% [markdown]
# # Converting PDF results of APMO 2010 to CSV

# %% [markdown]
# In the past, the results for APMO were reported in `PDF` format. We want to convert these to a more friendly `CSV` format for display and analysis.
#
# In the case of APMO 2010, after copying and pasting the ranked table from the PDF to the text file in `results_pre2016/apmo2010_res_text.txt,` and a bit of tweaking we get the following:
#
# ```
# 1 KOREA 10 265 1 2 4 3
# 2 RUSSIA 10 264 1 2 4 3
# ...
# 32 TRINIDAD_AND_TOBAGO 10 21 0 0 0 0
# 33 QATAR 10 0 0 0 0
# ```
#
# In other words, each row is a row of data, which we may directly read using `pandas.read_csv()`.We do this and perform some standarization. Then we save the info to `CSV`.

# %%
import pandas as pd

# We use a year variable for reusability.
year=2010

# %% [markdown]
# We open the file and split it by lines.

# %%
df=pd.read_csv('results_pre2016/apmo%s_res_text.txt' % year, sep=" ", header=None)
df.columns=['Rank', 'Country', '# of Contestants', 'Total Score', 'Gold Awards', 'Silver Awards', 'Bronze Awards', 'Honorable Mentions']
df
# Out:
#     Rank              Country  # of Contestants  Total Score  Gold Awards  \
# 0      1                KOREA                10          265            1
# 1      2               RUSSIA                10          264            1
# 2      3                  USA                10          236            1
# 3      4             THAILAND                10          223            1
# 4      5                JAPAN                10          221            1
# 5      6               CANADA                10          215            1
# 6      7            HONG_KONG                10          190            1
# 7      8            SINGAPORE                10          188            1
# 8      9            AUSTRALIA                10          185            1
# 9     10               TAIWAN                10          183            1
# 10    11           KAZAKHSTAN                10          179            1
# 11    12                 PERU                10          166            1
# 12    13            ARGENTINA                10          162            1
# 13    14               BRAZIL                10          143            0
# 14    15               MEXICO                10          143            0
# 15    16           AZERBAIJAN                10          124            0
# 16    17             MALAYSIA                10          122            0
# 17    18             COLOMBIA                10          103            0
# 18    19         TURKMENISTAN                10           97            0
# 19    20          NEW_ZEALAND                10           86            0
# 20    21           KYRGYZSTAN                10           84            0
# 21    22             CAMBODIA                10           83            0
# 22    23            INDONESIA                10           79            0
# 23    24           BANGLADESH                10           76            0
# 24    25          PHILIPPINES                 9           75            0
# 25    26           TAJIKISTAN                 9           70            0
# 26    27               PANAMA                 6           55            0
# 27    28          EL_SALVADOR                 7           41            0
# 28    29           COSTA_RICA                 7           35            0
# 29    30              ECUADOR                 5           35            0
# 30    31              URUGUAY                 5           35            0
# 31    32  TRINIDAD_AND_TOBAGO                10           21            0
# 32    33                QATAR                10            0            0
#
#     Silver Awards  Bronze Awards  Honorable Mentions
# 0               2              4                   3
# 1               2              4                   3
# 2               2              4                   3
# 3               2              4                   3
# 4               2              4                   3
# 5               2              4                   3
# 6               2              4                   3
# 7               2              4                   3
# 8               2              4                   3
# 9               2              4                   3
# 10              2              4                   3
# 11              1              5                   3
# 12              2              4                   3
# 13              3              4                   0
# 14              2              5                   1
# 15              2              2                   0
# 16              2              2                   1
# 17              0              3                   0
# 18              0              3                   0
# 19              0              1                   0
# 20              0              1                   0
# 21              0              1                   0
# 22              0              0                   1
# 23              0              0                   0
# 24              0              1                   0
# 25              0              0                   0
# 26              0              1                   0
# 27              0              0                   0
# 28              0              0                   0
# 29              0              1                   1
# 30              0              1                   0
# 31              0              0                   0
# 32              0              0                   0

# %% [markdown]
# From the information above, we note that we will need to change the name of some countries to get the standard country names that we are using.

# %%
df['Country']=df['Country'].str.title().str.replace('_', ' ')
df.loc[0,'Country']='Republic of Korea'
df.loc[2,'Country']='United States of America'
df.loc[31,'Country']='Trinidad and Tobago'
df
# Out:
#     Rank                   Country  # of Contestants  Total Score  \
# 0      1         Republic of Korea                10          265
# 1      2                    Russia                10          264
# 2      3  United States of America                10          236
# 3      4                  Thailand                10          223
# 4      5                     Japan                10          221
# 5      6                    Canada                10          215
# 6      7                 Hong Kong                10          190
# 7      8                 Singapore                10          188
# 8      9                 Australia                10          185
# 9     10                    Taiwan                10          183
# 10    11                Kazakhstan                10          179
# 11    12                      Peru                10          166
# 12    13                 Argentina                10          162
# 13    14                    Brazil                10          143
# 14    15                    Mexico                10          143
# 15    16                Azerbaijan                10          124
# 16    17                  Malaysia                10          122
# 17    18                  Colombia                10          103
# 18    19              Turkmenistan                10           97
# 19    20               New Zealand                10           86
# 20    21                Kyrgyzstan                10           84
# 21    22                  Cambodia                10           83
# 22    23                 Indonesia                10           79
# 23    24                Bangladesh                10           76
# 24    25               Philippines                 9           75
# 25    26                Tajikistan                 9           70
# 26    27                    Panama                 6           55
# 27    28               El Salvador                 7           41
# 28    29                Costa Rica                 7           35
# 29    30                   Ecuador                 5           35
# 30    31                   Uruguay                 5           35
# 31    32       Trinidad and Tobago                10           21
# 32    33                     Qatar                10            0
#
#     Gold Awards  Silver Awards  Bronze Awards  Honorable Mentions
# 0             1              2              4                   3
# 1             1              2              4                   3
# 2             1              2              4                   3
# 3             1              2              4                   3
# 4             1              2              4                   3
# 5             1              2              4                   3
# 6             1              2              4                   3
# 7             1              2              4                   3
# 8             1              2              4                   3
# 9             1              2              4                   3
# 10            1              2              4                   3
# 11            1              1              5                   3
# 12            1              2              4                   3
# 13            0              3              4                   0
# 14            0              2              5                   1
# 15            0              2              2                   0
# 16            0              2              2                   1
# 17            0              0              3                   0
# 18            0              0              3                   0
# 19            0              0              1                   0
# 20            0              0              1                   0
# 21            0              0              1                   0
# 22            0              0              0                   1
# 23            0              0              0                   0
# 24            0              0              1                   0
# 25            0              0              0                   0
# 26            0              0              1                   0
# 27            0              0              0                   0
# 28            0              0              0                   0
# 29            0              0              1                   1
# 30            0              0              1                   0
# 31            0              0              0                   0
# 32            0              0              0                   0

# %% [markdown]
# Now we add the ISO three letter code that we use for navigation on the website. We load the info from the `iso-alpha-3.csv` file.
#
# When we perform the merge, Pandas reorders the rows. This is an undesired behaviour, so we order back by rank. To do this, we first need to convert the rank column type to `int`.

# %%
codes=pd.read_csv('iso-alpha-3.csv')
data_coded=pd.merge(codes,df,left_on='country', right_on='Country', how='right').drop('country', axis=1)
data_coded['Rank']=data_coded.Rank.astype(int)
data_coded=data_coded.sort_values('Rank')
cols=data_coded.columns.tolist()
data_coded=data_coded[[cols[1],cols[0]]+cols[2:]]
data_coded.rename(columns={'code':'Code'}, inplace=True)
data_coded
# Out:
#     Rank Code                   Country  # of Contestants  Total Score  \
# 15     1  KOR         Republic of Korea                10          265
# 24     2  RUS                    Russia                10          264
# 31     3  USA  United States of America                10          236
# 28     4  THA                  Thailand                10          223
# 13     5  JPN                     Japan                10          221
# 6      6  CAN                    Canada                10          215
# 11     7  HKG                 Hong Kong                10          190
# 25     8  SGP                 Singapore                10          188
# 1      9  AUS                 Australia                10          185
# 26    10  TWN                    Taiwan                10          183
# 14    11  KAZ                Kazakhstan                10          179
# 21    12  PER                      Peru                10          166
# 0     13  ARG                 Argentina                10          162
# 4     14  BRA                    Brazil                10          143
# 18    15  MEX                    Mexico                10          143
# 2     16  AZE                Azerbaijan                10          124
# 17    17  MYS                  Malaysia                10          122
# 7     18  COL                  Colombia                10          103
# 30    19  TKM              Turkmenistan                10           97
# 19    20  NZL               New Zealand                10           86
# 16    21  KGZ                Kyrgyzstan                10           84
# 5     22  KHM                  Cambodia                10           83
# 12    23  IDN                 Indonesia                10           79
# 3     24  BGD                Bangladesh                10           76
# 22    25  PHL               Philippines                 9           75
# 27    26  TJK                Tajikistan                 9           70
# 20    27  PAN                    Panama                 6           55
# 10    28  SLV               El Salvador                 7           41
# 8     29  CRI                Costa Rica                 7           35
# 9     30  ECU                   Ecuador                 5           35
# 32    31  URY                   Uruguay                 5           35
# 29    32  TTO       Trinidad and Tobago                10           21
# 23    33  QAT                     Qatar                10            0
#
#     Gold Awards  Silver Awards  Bronze Awards  Honorable Mentions
# 15            1              2              4                   3
# 24            1              2              4                   3
# 31            1              2              4                   3
# 28            1              2              4                   3
# 13            1              2              4                   3
# 6             1              2              4                   3
# 11            1              2              4                   3
# 25            1              2              4                   3
# 1             1              2              4                   3
# 26            1              2              4                   3
# 14            1              2              4                   3
# 21            1              1              5                   3
# 0             1              2              4                   3
# 4             0              3              4                   0
# 18            0              2              5                   1
# 2             0              2              2                   0
# 17            0              2              2                   1
# 7             0              0              3                   0
# 30            0              0              3                   0
# 19            0              0              1                   0
# 16            0              0              1                   0
# 5             0              0              1                   0
# 12            0              0              0                   1
# 3             0              0              0                   0
# 22            0              0              1                   0
# 27            0              0              0                   0
# 20            0              0              1                   0
# 10            0              0              0                   0
# 8             0              0              0                   0
# 9             0              0              1                   1
# 32            0              0              1                   0
# 29            0              0              0                   0
# 23            0              0              0                   0

# %% [markdown]
# Now the information is exactly in the form that we need. We save the work.

# %%
data_coded.to_csv('reports/by_country_ranked_%s.csv' % year,index=False)
