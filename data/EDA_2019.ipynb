# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

year=2019
df=pd.read_csv('data_clean/scoretable-{}-clean.csv'.format(year))
probs=df.loc[:,'p1':'p5']
sns.swarmplot(data=probs)

# %%
df[df.p5>=7]
# Out:
#     code                   country  rank              last  \
# 0    ARG                 Argentina     1            LIWSKI
# 22   BRA                    Brazil     1      Gomes Cabral
# 42   CAN                    Canada     1              Rong
# 89   HKG                 Hong Kong     1            Leung
# 109  IDN                 Indonesia     1        Nitisastro
# 110  IDN                 Indonesia     2           Tjowasi
# 119  IRN  Islamic Republic of Iran     1         Mohammadi
# 120  IRN  Islamic Republic of Iran     2  Ghahremani Koure
# 123  IRN  Islamic Republic of Iran     5            Talaei
# 124  IRN  Islamic Republic of Iran     6     Mirzaei Anari
# 139  KAZ                Kazakhstan     1       Duisenbekov
# 150  KOR         Republic of Korea     2               Noh
# 152  KOR         Republic of Korea     4               Kim
# 153  KOR         Republic of Korea     5               Seo
# 154  KOR         Republic of Korea     6               Kim
# ...

# %%
print(probs.corr())
sns.heatmap(probs.corr(), cmap='gray')
# Out:
#           p1        p2        p3        p4        p5
# p1  1.000000  0.482438  0.234201  0.039541  0.220957
# p2  0.482438  1.000000  0.259143  0.059547  0.316645
# p3  0.234201  0.259143  1.000000  0.079585  0.253161
# p4  0.039541  0.059547  0.079585  1.000000  0.048158
# p5  0.220957  0.316645  0.253161  0.048158  1.000000

# %%
probs.describe()
# Out:
#                p1          p2          p3          p4          p5
# count  359.000000  359.000000  359.000000  359.000000  359.000000
# mean     5.465181    4.111421    1.013928    0.044568    1.025070
# std      2.654876    3.060627    1.903342    0.493779    2.184745
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      4.500000    0.500000    0.000000    0.000000    0.000000
# 50%      7.000000    6.000000    0.000000    0.000000    0.000000
# 75%      7.000000    7.000000    1.000000    0.000000    1.000000
# max      7.000000    7.000000    7.000000    7.000000    7.000000

# %%
increasing=(probs.p1<=probs.p2)&(probs.p2<=probs.p3)&(probs.p3<=probs.p4)&(probs.p4<=probs.p5)
decreasing=(probs.p1>=probs.p2)&(probs.p2>=probs.p3)&(probs.p3>=probs.p4)&(probs.p4>=probs.p5)
display(df[increasing])
display(df[decreasing])
print(df[decreasing].shape)
# Out:
#     code              country  rank             last          first sex  p1  \
# 41   KHM             Cambodia    10        SOVANNARA          HOUNG   M   0
# 68   CRI           Costa Rica     7  Brenes Calderón  José Leonardo   M   0
# 69   CRI           Costa Rica     8    Vásquez Sandí       Maricruz   F   0
# 74   ECU              Ecuador     5         Zambrano       Leonardo   M   0
# 75   ECU              Ecuador     6               Wu         Zhiron   F   0
# 76   ECU              Ecuador     7          Soriano       Julianne   F   0
# 77   ECU              Ecuador     8         Gallegos      Stephanie   F   0
# 78   ECU              Ecuador     9    Zurita Doumet         Salomé   F   0
# 79   ECU              Ecuador    10    Zurita Doumet   Ana Victoria   F   0
# 84   SLV          El Salvador     5       Cerna Meza  Andrea Nicole   F   0
# 85   SLV          El Salvador     6     Morales Peña  Ricardo Josué   M   0
# ...

# %%
df['sex']=df.sex.str.replace(' ','')

# %%
df.groupby('sex').mean()
# Out:
#          rank        p1        p2        p3        p4        p5      total
# sex
# F    5.942857  3.142857  1.828571  0.714286  0.028571  0.571429   6.285714
# M    5.141975  5.716049  4.358025  1.046296  0.046296  1.074074  12.240741

# %%
df.groupby('sex').count()
# Out:
#      code  country  rank  last  first   p1   p2   p3   p4   p5  total
# sex
# F      36       36    36    36     36   36   36   36   36   36     36
# M     323      323   323   323    323  323  323  323  323  323    323

# %%
male=df[df.sex=='M'].total
female=df[df.sex=='F'].total
diff_means=male.mean()-female.mean()
print(len(male),len(female), diff_means)
# Out:
# 324 35 5.955026455026455

# %%
reps=np.empty(50000)
for j in range(50000):
    perm=np.random.permutation(df.total)
    r_male=perm[:len(male)]
    r_female=perm[len(male):]
    reps[j]=r_male.mean()-r_female.mean()
    
print(reps.max(),reps.min())
plt.hist(reps,bins=20)
plt.show()
# Out:
# 5.005291005291006 -4.9985890652557305

# %%
df[df.sex=='F'].groupby('country')['first'].count().sort_values(ascending=False)
# Out:
# country
# Ecuador                     7
# Macedonia                   4
# United Arab Emirates        2
# Cambodia                    2
# Costa Rica                  2
# Saudi Arabia                2
# Russia                      2
# Peru                        2
# Trinidad and Tobago         2
# Islamic Republic of Iran    1
# Bolivia                     1
# El Salvador                 1
# New Zealand                 1
# Kyrgyzstan                  1
# Pakistan                    1
# Singapore                   1
# Sri Lanka                   1
# Thailand                    1
# Argentina                   1
# Name: first, dtype: int64

# %%
df[df.country=='Ecuador']
# Out:
#    code  country  rank               last              first sex  p1  p2  p3  \
# 70  ECU  Ecuador     1      Barco Santana  Valeria Estefania   F   7   0   0
# 71  ECU  Ecuador     2                 Yu            Giacomo  M    2   0   0
# 72  ECU  Ecuador     3  Indacochea Rosado      María Gratzia   F   0   1   0
# 73  ECU  Ecuador     4             Suarez              Pedro   M   0   1   0
# 74  ECU  Ecuador     5           Zambrano           Leonardo   M   0   0   0
# 75  ECU  Ecuador     6                 Wu             Zhiron   F   0   0   0
# 76  ECU  Ecuador     7            Soriano           Julianne   F   0   0   0
# 77  ECU  Ecuador     8           Gallegos          Stephanie   F   0   0   0
# 78  ECU  Ecuador     9      Zurita Doumet             Salomé   F   0   0   0
# 79  ECU  Ecuador    10      Zurita Doumet       Ana Victoria   F   0   0   0
#
#     p4  p5  total
# 70   0   0      7
# 71   0   0      2
# 72   0   0      1
# 73   0   0      1
# 74   0   1      1
# ...

# %%
df[['country','total']].join(pd.DataFrame((probs==7).sum(axis=1),columns=['solved'])).groupby('country').sum().sort_values('solved',ascending=False)
# Out:
#                           total  solved
# country
# Republic of Korea           240      29
# United States of America    212      26
# Singapore                   202      24
# Russia                      194      24
# Thailand                    200      23
# Indonesia                   167      21
# Canada                      162      20
# Brazil                      156      19
# Taiwan                      159      19
# India                       156      19
# Islamic Republic of Iran    193      19
# Mexico                      139      17
# Japan                       167      17
# Kazakhstan                  154      17
# Hong Kong                   132      17
# Argentina                   141      16
# Peru                        132      15
# Bangladesh                  109      14
# Saudi Arabia                116      13
# Philippines                 102      12
# Tajikistan                   92      11
# Syria                       100      11
# ...

# %%
df['mean']=np.mean(probs, axis=1)
df['std']=np.std(probs, axis=1)

# %%
df[(df['mean']>4)&(df['mean']<4.5)&(df['std']<2.6)]
# Out:
#     code                   country  rank     last        first sex  p1  p2  \
# 122  IRN  Islamic Republic of Iran     4  Bagheri  Amirhossein   M   7   6
#
#      p3  p4  p5  total  mean       std
# 122   3   0   5     21   4.2  2.481935

# %%
plt.scatter(df['mean'],df['std'])
plt.xlabel('Mean')
plt.ylabel('Standard Deviation')
plt.title('Mean vs. STD')
# Out:
# Text(0.5,1,'Mean vs. STD')

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource

source = ColumnDataSource(df)

TT = [
    ("Country", "$country"),
    ("Rank", "$rank")
]

q = figure(plot_width=600, plot_height=400, title='Intento', tooltips=TT)

# add a circle renderer with a size, color, and alpha
q.circle('mean', 'std', source=source, size=5, color="green", alpha=0.5)

# show the results
show(q)

# %%
df.sort_values('total',ascending=False).head()
# Out:
#     code                   country  rank last     first sex  p1  p2  p3  p4  \
# 150  KOR         Republic of Korea     2  Noh  Taeyeong   M   7   7   7   0
# 149  KOR         Republic of Korea     1  Cho  Youngjun   M   7   7   7   6
# 261  SGP                 Singapore     1   Ng   Yu Peng   M   7   7   7   0
# 345  USA  United States of America     1  Wan    Edward   M   7   7   7   0
# 151  KOR         Republic of Korea     3  Kim     Jimin   M   7   7   7   0
#
#      p5  total  mean       std
# 150   7     28   5.6  2.800000
# 149   1     28   5.6  2.332381
# 261   7     28   5.6  2.800000
# 345   7     28   5.6  2.800000
# 151   6     27   5.4  2.727636

# %%
df[df.p4>0]
# Out:
#     code               country  rank               last           first sex  \
# 135  JPN                 Japan     7            Kentaro      Matsushita   M
# 149  KOR     Republic of Korea     1                Cho        Youngjun   M
# 258  SAU          Saudi Arabia     8         Daghistani         Ghadeer   F
# 262  SGP             Singapore     2                Boo  Tse Yang Lucas   M
# 339  ARE  United Arab Emirates     5  Satvik Nimmagadda         Krishna   M
#
#      p1  p2  p3  p4  p5  total  mean       std
# 135   7   7   0   1   0     15   3.0  3.286335
# 149   7   7   7   6   1     28   5.6  2.332381
# 258   7   0   1   1   1     10   2.0  2.529822
# 262   7   7   0   7   4     25   5.0  2.756810
# 339   1   0   0   1   0      2   0.4  0.489898

# %%
from sklearn.cluster import KMeans

krange=range(1,8)
inertias=[]

for k in krange:
    model=KMeans(n_clusters=k)
    model.fit(probs)
    inertias.append(model.inertia_)
    
plt.plot(inertias)
plt.show()

# %%
model=KMeans(n_clusters=4)
model.fit(probs)
labels=model.labels_
df['labels']=labels

# %%
df['labels'].value_counts()
# Out:
# 0    158
# 2     83
# 1     74
# 3     44
# Name: labels, dtype: int64

# %%
sns.swarmplot(x='labels', y='total', data=df)

# %%
df[df.labels==0]

# %%
df[(df.labels==1)&(df.total>25)]
