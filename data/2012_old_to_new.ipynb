# %% [markdown]
# # Converting PDF results of APMO 2012 to CSV

# %% [markdown]
# In the past, the results for APMO were reported in `PDF` format. We want to convert these to a more friendly `CSV` format for display and analysis.
#
# In the case of APMO 2012, after copying and pasting the ranked table from the PDF to the text file in `results_pre2016/apmo2012_res_text.txt,` and a bit of tweaking we get the following:
#
# ```
# 1 KOREA 10 333 1 2 4 3
# 2 USA 10 283 1 2 4 3
# ...
# 36 TRINIDAD_AND_TOBAGO 10 9 0 0 0 0
# 37 QATAR 3 5 0 0 0 0
# ```
#
# In other words, each row is a row of data, which we may directly read using `pandas.read_csv()`.We do this and perform some standarization. Then we save the info to `CSV`.

# %%
import pandas as pd

# We use a year variable for reusability.
year=2012

# %% [markdown]
# We open the file and split it by lines.

# %%
df=pd.read_csv('results_pre2016/apmo%s_res_text.txt' % year, sep=" ", header=None)
df.columns=['Rank', 'Country', '# of Contestants', 'Total Score', 'Gold Awards', 'Silver Awards', 'Bronze Awards', 'Honorable Mentions']
df
# Out:
#     Rank              Country  # of Contestants  Total Score  Gold Awards  \
# 0      1                KOREA                10          333            1
# 1      2                  USA                10          283            1
# 2      3             THAILAND                10          279            1
# 3      4               RUSSIA                10          249            1
# 4      5                JAPAN                10          241            1
# 5      6               TAIWAN                10          232            1
# 6      7                 PERU                10          227            1
# 7      8            SINGAPORE                10          217            1
# 8      9            HONG_KONG                10          214            1
# 9     10               CANADA                10          209            1
# 10    11               BRAZIL                10          202            1
# 11    12               MEXICO                10          177            1
# 12    13            INDONESIA                10          176            1
# 13    14           KAZAKHSTAN                10          167            0
# 14    15            AUSTRALIA                10          154            1
# 15    16             MALAYSIA                10          150            1
# 16    17            ARGENTINA                10          126            0
# 17    18         TURKMENISTAN                10          115            0
# 18    19           BANGLADESH                10          105            0
# 19    20          PHILIPPINES                10           97            0
# 20    21          NEW_ZEALAND                10           81            0
# 21    22         SAUDI_ARABIA                10           78            1
# 22    23             COLOMBIA                10           76            0
# 23    24           AZERBAIJAN                 9           68            0
# 24    25              URUGUAY                 5           66            0
# 25    26           TAJIKISTAN                 9           63            0
# 26    27             PAKISTAN                10           60            0
# 27    28              MOROCOO                10           49            0
# 28    29          EL_SALVADOR                 4           46            0
# 29    30             CAMBODIA                10           45            0
# 30    31           Costa_Rica                10           45            0
# 31    32                SYRIA                 6           35            0
# 32    33              ECUADOR                 8           28            0
# 33    34           KYRGYZSTAN                 4           28            0
# 34    35               PANAMA                 5           21            0
# 35    36  TRINIDAD_AND_TOBAGO                10            9            0
# 36    37                QATAR                 3            5            0
#
#     Silver Awards  Bronze Awards  Honorable Mentions
# 0               2              4                   3
# 1               2              4                   3
# 2               2              4                   3
# 3               2              4                   3
# 4               2              4                   3
# 5               2              4                   3
# 6               2              4                   3
# 7               2              4                   3
# 8               2              4                   3
# 9               2              4                   3
# 10              2              4                   3
# 11              2              4                   3
# 12              2              4                   3
# 13              3              4                   3
# 14              1              5                   3
# 15              2              2                   0
# 16              1              4                   5
# 17              1              4                   2
# 18              1              2                   2
# 19              1              1                   4
# 20              0              2                   4
# 21              0              0                   3
# 22              1              0                   3
# 23              0              1                   4
# 24              0              3                   2
# 25              0              2                   1
# 26              0              1                   2
# 27              0              0                   2
# 28              1              1                   0
# 29              0              0                   1
# 30              0              0                   3
# 31              0              0                   2
# 32              1              0                   0
# 33              0              0                   0
# 34              0              0                   0
# 35              0              0                   0
# 36              0              0                   0

# %% [markdown]
# From the information above, we note that we will need to change the name of some countries to get the standard country names that we are using.

# %%
df['Country']=df['Country'].str.title().str.replace('_', ' ')
df.loc[0,'Country']='Republic of Korea'
df.loc[1,'Country']='United States of America'
df.loc[35,'Country']='Trinidad and Tobago'
df
# Out:
#     Rank                   Country  # of Contestants  Total Score  \
# 0      1         Republic of Korea                10          333
# 1      2  United States of America                10          283
# 2      3                  Thailand                10          279
# 3      4                    Russia                10          249
# 4      5                     Japan                10          241
# 5      6                    Taiwan                10          232
# 6      7                      Peru                10          227
# 7      8                 Singapore                10          217
# 8      9                 Hong Kong                10          214
# 9     10                    Canada                10          209
# 10    11                    Brazil                10          202
# 11    12                    Mexico                10          177
# 12    13                 Indonesia                10          176
# 13    14                Kazakhstan                10          167
# 14    15                 Australia                10          154
# 15    16                  Malaysia                10          150
# 16    17                 Argentina                10          126
# 17    18              Turkmenistan                10          115
# 18    19                Bangladesh                10          105
# 19    20               Philippines                10           97
# 20    21               New Zealand                10           81
# 21    22              Saudi Arabia                10           78
# 22    23                  Colombia                10           76
# 23    24                Azerbaijan                 9           68
# 24    25                   Uruguay                 5           66
# 25    26                Tajikistan                 9           63
# 26    27                  Pakistan                10           60
# 27    28                   Morocoo                10           49
# 28    29               El Salvador                 4           46
# 29    30                  Cambodia                10           45
# 30    31                Costa Rica                10           45
# 31    32                     Syria                 6           35
# 32    33                   Ecuador                 8           28
# 33    34                Kyrgyzstan                 4           28
# 34    35                    Panama                 5           21
# 35    36       Trinidad and Tobago                10            9
# 36    37                     Qatar                 3            5
#
#     Gold Awards  Silver Awards  Bronze Awards  Honorable Mentions
# 0             1              2              4                   3
# 1             1              2              4                   3
# 2             1              2              4                   3
# 3             1              2              4                   3
# 4             1              2              4                   3
# 5             1              2              4                   3
# 6             1              2              4                   3
# 7             1              2              4                   3
# 8             1              2              4                   3
# 9             1              2              4                   3
# 10            1              2              4                   3
# 11            1              2              4                   3
# 12            1              2              4                   3
# 13            0              3              4                   3
# 14            1              1              5                   3
# 15            1              2              2                   0
# 16            0              1              4                   5
# 17            0              1              4                   2
# 18            0              1              2                   2
# 19            0              1              1                   4
# 20            0              0              2                   4
# 21            1              0              0                   3
# 22            0              1              0                   3
# 23            0              0              1                   4
# 24            0              0              3                   2
# 25            0              0              2                   1
# 26            0              0              1                   2
# 27            0              0              0                   2
# 28            0              1              1                   0
# 29            0              0              0                   1
# 30            0              0              0                   3
# 31            0              0              0                   2
# 32            0              1              0                   0
# 33            0              0              0                   0
# 34            0              0              0                   0
# 35            0              0              0                   0
# 36            0              0              0                   0

# %% [markdown]
# Now we add the ISO three letter code that we use for navigation on the website. We load the info from the `iso-alpha-3.csv` file.
#
# When we perform the merge, Pandas reorders the rows. This is an undesired behaviour, so we order back by rank. To do this, we first need to convert the rank column type to `int`.

# %%
codes=pd.read_csv('iso-alpha-3.csv')
data_coded=pd.merge(codes,df,left_on='country', right_on='Country', how='right').drop('country', axis=1)
data_coded['Rank']=data_coded.Rank.astype(int)
data_coded=data_coded.sort_values('Rank')
cols=data_coded.columns.tolist()
data_coded=data_coded[[cols[1],cols[0]]+cols[2:]]
data_coded.rename(columns={'code':'Code'}, inplace=True)
data_coded
# Out:
#     Rank Code                   Country  # of Contestants  Total Score  \
# 15     1  KOR         Republic of Korea                10          333
# 34     2  USA  United States of America                10          283
# 31     3  THA                  Thailand                10          279
# 25     4  RUS                    Russia                10          249
# 13     5  JPN                     Japan                10          241
# 29     6  TWN                    Taiwan                10          232
# 22     7  PER                      Peru                10          227
# 27     8  SGP                 Singapore                10          217
# 11     9  HKG                 Hong Kong                10          214
# 6     10  CAN                    Canada                10          209
# 4     11  BRA                    Brazil                10          202
# 18    12  MEX                    Mexico                10          177
# 12    13  IDN                 Indonesia                10          176
# 14    14  KAZ                Kazakhstan                10          167
# 1     15  AUS                 Australia                10          154
# 17    16  MYS                  Malaysia                10          150
# 0     17  ARG                 Argentina                10          126
# 33    18  TKM              Turkmenistan                10          115
# 3     19  BGD                Bangladesh                10          105
# 23    20  PHL               Philippines                10           97
# 19    21  NZL               New Zealand                10           81
# 26    22  SAU              Saudi Arabia                10           78
# 7     23  COL                  Colombia                10           76
# 2     24  AZE                Azerbaijan                 9           68
# 35    25  URY                   Uruguay                 5           66
# 30    26  TJK                Tajikistan                 9           63
# 20    27  PAK                  Pakistan                10           60
# 36    28  NaN                   Morocoo                10           49
# 10    29  SLV               El Salvador                 4           46
# 5     30  KHM                  Cambodia                10           45
# 8     31  CRI                Costa Rica                10           45
# 28    32  SYR                     Syria                 6           35
# 9     33  ECU                   Ecuador                 8           28
# 16    34  KGZ                Kyrgyzstan                 4           28
# 21    35  PAN                    Panama                 5           21
# 32    36  TTO       Trinidad and Tobago                10            9
# 24    37  QAT                     Qatar                 3            5
#
#     Gold Awards  Silver Awards  Bronze Awards  Honorable Mentions
# 15            1              2              4                   3
# 34            1              2              4                   3
# 31            1              2              4                   3
# 25            1              2              4                   3
# 13            1              2              4                   3
# 29            1              2              4                   3
# 22            1              2              4                   3
# 27            1              2              4                   3
# 11            1              2              4                   3
# 6             1              2              4                   3
# 4             1              2              4                   3
# 18            1              2              4                   3
# 12            1              2              4                   3
# 14            0              3              4                   3
# 1             1              1              5                   3
# 17            1              2              2                   0
# 0             0              1              4                   5
# 33            0              1              4                   2
# 3             0              1              2                   2
# 23            0              1              1                   4
# 19            0              0              2                   4
# 26            1              0              0                   3
# 7             0              1              0                   3
# 2             0              0              1                   4
# 35            0              0              3                   2
# 30            0              0              2                   1
# 20            0              0              1                   2
# 36            0              0              0                   2
# 10            0              1              1                   0
# 5             0              0              0                   1
# 8             0              0              0                   3
# 28            0              0              0                   2
# 9             0              1              0                   0
# 16            0              0              0                   0
# 21            0              0              0                   0
# 32            0              0              0                   0
# 24            0              0              0                   0

# %% [markdown]
# Now the information is exactly in the form that we need. We save the work.

# %%
data_coded.to_csv('reports/by_country_ranked_%s.csv' % year,index=False)
